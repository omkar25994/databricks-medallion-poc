# %%
# %sql

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
df = spark.read.csv("/Workspace/Users/om1821@gmail.com/medallion_poc/suzuki_stock_data2.csv", header=True)

df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("new.default.suzuki_stock")

display(df)
